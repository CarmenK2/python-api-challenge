# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Starting URL for Weather Map API Call
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
# Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | saskylakh
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | talnakh
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | rincon
# Processing Record 9 of Set 1 | ciudad bolivar
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 1 | tanshui
# City not found. Skipping...
# Processing Record 13 of Set 1 | khatanga
# Processing Record 14 of Set 1 | puerto escondido
# Processing Record 15 of Set 1 | yulara
# Processing Record 16 of Set 1 | high prairie
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | komsomolskiy
# Processing Record 19 of Set 1 | kahului
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | dolores
# Processing Record 22 of Set 1 | beloha
# Processing Record 23 of Set 1 | mehriz
# Processing Record 24 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | moroni
# Processing Record 28 of Set 1 | povenets
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | isangel
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | riyadh
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | blackwater
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 1 | caravelas
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | mahibadhoo
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | miass
# Processing Record 44 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 1 | vila franca do campo
# Processing Record 46 of Set 1 | road town
# Processing Record 47 of Set 1 | tiarei
# Processing Record 48 of Set 1 | esperance
# Processing Record 49 of Set 1 | ginir
# Processing Record 50 of Set 1 | port alfred
# Processing Record 0 of Set 2 | dikson
# Processing Record 1 of Set 2 | kangaatsiaq
# Processing Record 2 of Set 2 | camacha
# Processing Record 3 of Set 2 | punta arenas
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | souillac
# Processing Record 6 of Set 2 | sistranda
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | zhezkazgan
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | callaway
# Processing Record 12 of Set 2 | kaitangata
# Processing Record 13 of Set 2 | campoverde
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | fare
# Processing Record 16 of Set 2 | kavieng
# Processing Record 17 of Set 2 | hualmay
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | coquimbo
# Processing Record 23 of Set 2 | boyolangu
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | tuatapere
# Processing Record 26 of Set 2 | rani
# Processing Record 27 of Set 2 | lazaro cardenas
# Processing Record 28 of Set 2 | pochutla
# Processing Record 29 of Set 2 | rassvet
# Processing Record 30 of Set 2 | lae
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | huarmey
# Processing Record 33 of Set 2 | olhao
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | leh
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | aswan
# Processing Record 38 of Set 2 | airai
# Processing Record 39 of Set 2 | korla
# Processing Record 40 of Set 2 | san juan del sur
# Processing Record 41 of Set 2 | mayumba
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | ilebo
# Processing Record 44 of Set 2 | tzucacab
# Processing Record 45 of Set 2 | karratha
# Processing Record 46 of Set 2 | metehara
# City not found. Skipping...
# Processing Record 47 of Set 2 | lewistown
# Processing Record 48 of Set 2 | baherden
# Processing Record 49 of Set 2 | kodiak
# Processing Record 0 of Set 3 | cidreira
# Processing Record 1 of Set 3 | kihei
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | berlevag
# Processing Record 5 of Set 3 | porto novo
# Processing Record 6 of Set 3 | iwanai
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | castro
# Processing Record 10 of Set 3 | andenes
# Processing Record 11 of Set 3 | nelson bay
# Processing Record 12 of Set 3 | plettenberg bay
# Processing Record 13 of Set 3 | gorontalo
# Processing Record 14 of Set 3 | srednekolymsk
# Processing Record 15 of Set 3 | smithers
# Processing Record 16 of Set 3 | rocha
# Processing Record 17 of Set 3 | leningradskiy
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | amarante do maranhao
# Processing Record 20 of Set 3 | brive-la-gaillarde
# Processing Record 21 of Set 3 | sao miguel do tapuio
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | jumla
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | mahebourg
# Processing Record 26 of Set 3 | tomatlan
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | kilindoni
# Processing Record 29 of Set 3 | talaja
# Processing Record 30 of Set 3 | suffolk
# Processing Record 31 of Set 3 | pevek
# Processing Record 32 of Set 3 | payson
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 3 | la ronge
# Processing Record 36 of Set 3 | bluff
# Processing Record 37 of Set 3 | calbuco
# Processing Record 38 of Set 3 | temiscaming
# Processing Record 39 of Set 3 | upernavik
# Processing Record 40 of Set 3 | de-kastri
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | adrar
# Processing Record 43 of Set 3 | yar-sale
# Processing Record 44 of Set 3 | oga
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | praia da vitoria
# Processing Record 47 of Set 3 | avarua
# Processing Record 48 of Set 3 | zyryanka
# Processing Record 49 of Set 3 | torbay
# Processing Record 0 of Set 4 | port keats
# Processing Record 1 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | fortuna
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | rameshki
# Processing Record 7 of Set 4 | sola
# Processing Record 8 of Set 4 | linxia
# Processing Record 9 of Set 4 | price
# Processing Record 10 of Set 4 | tessalit
# Processing Record 11 of Set 4 | hovd
# Processing Record 12 of Set 4 | beringovskiy
# Processing Record 13 of Set 4 | imbituba
# Processing Record 14 of Set 4 | saint george
# Processing Record 15 of Set 4 | boden
# Processing Record 16 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 4 | codrington
# Processing Record 18 of Set 4 | pangai
# Processing Record 19 of Set 4 | vestmannaeyjar
# Processing Record 20 of Set 4 | gonen
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | faanui
# Processing Record 23 of Set 4 | jiuquan
# Processing Record 24 of Set 4 | hambantota
# Processing Record 25 of Set 4 | masumbwe
# Processing Record 26 of Set 4 | luderitz
# Processing Record 27 of Set 4 | samarai
# Processing Record 28 of Set 4 | barranca
# Processing Record 29 of Set 4 | severnyy
# Processing Record 30 of Set 4 | edd
# Processing Record 31 of Set 4 | bintulu
# Processing Record 32 of Set 4 | pisco
# Processing Record 33 of Set 4 | svetlyy
# Processing Record 34 of Set 4 | atlantic beach
# Processing Record 35 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 4 | katubao
# Processing Record 37 of Set 4 | nhulunbuy
# Processing Record 38 of Set 4 | katsuura
# Processing Record 39 of Set 4 | paamiut
# Processing Record 40 of Set 4 | east london
# Processing Record 41 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 4 | kavaratti
# Processing Record 43 of Set 4 | whitehorse
# Processing Record 44 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 4 | jacareacanga
# Processing Record 46 of Set 4 | bud
# Processing Record 47 of Set 4 | tigil
# Processing Record 48 of Set 4 | jalu
# Processing Record 49 of Set 4 | madang
# Processing Record 0 of Set 5 | bulgan
# Processing Record 1 of Set 5 | saint-pierre
# Processing Record 2 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 5 | richards bay
# Processing Record 4 of Set 5 | antofagasta
# Processing Record 5 of Set 5 | chicama
# Processing Record 6 of Set 5 | alot
# Processing Record 7 of Set 5 | waddan
# Processing Record 8 of Set 5 | vao
# Processing Record 9 of Set 5 | geraldton
# Processing Record 10 of Set 5 | nuevo progreso
# Processing Record 11 of Set 5 | severo-kurilsk
# Processing Record 12 of Set 5 | namanyere
# Processing Record 13 of Set 5 | helena
# Processing Record 14 of Set 5 | linqiong
# Processing Record 15 of Set 5 | homagama
# Processing Record 16 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 5 | shimoda
# Processing Record 18 of Set 5 | lakes entrance
# Processing Record 19 of Set 5 | poltavka
# Processing Record 20 of Set 5 | thinadhoo
# Processing Record 21 of Set 5 | port hueneme
# Processing Record 22 of Set 5 | provideniya
# Processing Record 23 of Set 5 | tiksi
# Processing Record 24 of Set 5 | gupitan
# Processing Record 25 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | markova
# Processing Record 27 of Set 5 | nuuk
# Processing Record 28 of Set 5 | agua dulce
# Processing Record 29 of Set 5 | bengkulu
# Processing Record 30 of Set 5 | isiro
# Processing Record 31 of Set 5 | khunti
# Processing Record 32 of Set 5 | lasa
# Processing Record 33 of Set 5 | ye
# City not found. Skipping...
# Processing Record 34 of Set 5 | sulangan
# Processing Record 35 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 5 | sosnogorsk
# Processing Record 37 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 5 | chapleau
# Processing Record 39 of Set 5 | lompoc
# Processing Record 40 of Set 5 | singaraja
# Processing Record 41 of Set 5 | portland
# Processing Record 42 of Set 5 | balikpapan
# Processing Record 43 of Set 5 | pangody
# Processing Record 44 of Set 5 | gwanda
# Processing Record 45 of Set 5 | khani
# Processing Record 46 of Set 5 | manacapuru
# Processing Record 47 of Set 5 | nioro
# Processing Record 48 of Set 5 | kobayashi
# Processing Record 49 of Set 5 | durban
# Processing Record 0 of Set 6 | youhao
# Processing Record 1 of Set 6 | port blair
# Processing Record 2 of Set 6 | klyuchi
# Processing Record 3 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 6 | asosa
# Processing Record 5 of Set 6 | hervey bay
# Processing Record 6 of Set 6 | shenjiamen
# Processing Record 7 of Set 6 | raudeberg
# Processing Record 8 of Set 6 | zhanaozen
# Processing Record 9 of Set 6 | kandrian
# Processing Record 10 of Set 6 | nanortalik
# Processing Record 11 of Set 6 | esmeraldas
# Processing Record 12 of Set 6 | lekoni
# Processing Record 13 of Set 6 | halifax
# Processing Record 14 of Set 6 | ciudad guayana
# Processing Record 15 of Set 6 | sorong
# Processing Record 16 of Set 6 | nemuro
# Processing Record 17 of Set 6 | sisimiut
# Processing Record 18 of Set 6 | gerash
# Processing Record 19 of Set 6 | gondanglegi
# Processing Record 20 of Set 6 | touros
# Processing Record 21 of Set 6 | aksarka
# Processing Record 22 of Set 6 | salinas
# Processing Record 23 of Set 6 | carnarvon
# Processing Record 24 of Set 6 | wajir
# Processing Record 25 of Set 6 | grindavik
# Processing Record 26 of Set 6 | dukat
# Processing Record 27 of Set 6 | kieta
# Processing Record 28 of Set 6 | amazar
# Processing Record 29 of Set 6 | darhan
# Processing Record 30 of Set 6 | kalemie
# Processing Record 31 of Set 6 | baoshan
# Processing Record 32 of Set 6 | bathsheba
# Processing Record 33 of Set 6 | iguai
# Processing Record 34 of Set 6 | takoradi
# Processing Record 35 of Set 6 | amga
# Processing Record 36 of Set 6 | ouango
# Processing Record 37 of Set 6 | pangkalanbuun
# Processing Record 38 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 39 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 40 of Set 6 | saint-augustin
# Processing Record 41 of Set 6 | shingu
# Processing Record 42 of Set 6 | tilichiki
# Processing Record 43 of Set 6 | vostok
# Processing Record 44 of Set 6 | lindi
# Processing Record 45 of Set 6 | arlit
# Processing Record 46 of Set 6 | kaoma
# Processing Record 47 of Set 6 | hvide sande
# Processing Record 48 of Set 6 | sioux lookout
# Processing Record 49 of Set 6 | preobrazheniye
# Processing Record 0 of Set 7 | opunake
# Processing Record 1 of Set 7 | kizilskoye
# Processing Record 2 of Set 7 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 3 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 7 | neiafu
# Processing Record 5 of Set 7 | namatanai
# Processing Record 6 of Set 7 | barinitas
# Processing Record 7 of Set 7 | panormos
# Processing Record 8 of Set 7 | sibay
# Processing Record 9 of Set 7 | belaya gora
# Processing Record 10 of Set 7 | ossora
# Processing Record 11 of Set 7 | nome
# Processing Record 12 of Set 7 | fairbanks
# Processing Record 13 of Set 7 | saint anthony
# Processing Record 14 of Set 7 | skjervoy
# Processing Record 15 of Set 7 | ordzhonikidze
# Processing Record 16 of Set 7 | cairns
# Processing Record 17 of Set 7 | ulladulla
# Processing Record 18 of Set 7 | havre-saint-pierre
# Processing Record 19 of Set 7 | sidney
# Processing Record 20 of Set 7 | kungurtug
# Processing Record 21 of Set 7 | acapulco
# Processing Record 22 of Set 7 | tura
# Processing Record 23 of Set 7 | taoudenni
# Processing Record 24 of Set 7 | nunoa
# Processing Record 25 of Set 7 | kruisfontein
# Processing Record 26 of Set 7 | tazovskiy
# Processing Record 27 of Set 7 | tevaitoa
# Processing Record 28 of Set 7 | qui nhon
# Processing Record 29 of Set 7 | fukue
# Processing Record 30 of Set 7 | gurjaani
# Processing Record 31 of Set 7 | clyde river
# Processing Record 32 of Set 7 | sokoto
# Processing Record 33 of Set 7 | gushikawa
# Processing Record 34 of Set 7 | harper
# Processing Record 35 of Set 7 | nisia floresta
# Processing Record 36 of Set 7 | sitka
# Processing Record 37 of Set 7 | governador valadares
# Processing Record 38 of Set 7 | jaciara
# Processing Record 39 of Set 7 | krasnoselkup
# Processing Record 40 of Set 7 | mount gambier
# Processing Record 41 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 7 | alma
# Processing Record 43 of Set 7 | yumen
# Processing Record 44 of Set 7 | zolotukhino
# Processing Record 45 of Set 7 | ankazoabo
# Processing Record 46 of Set 7 | okhotsk
# Processing Record 47 of Set 7 | puerto madero
# Processing Record 48 of Set 7 | villanueva
# Processing Record 49 of Set 7 | ponta delgada
# Processing Record 0 of Set 8 | taiyuan
# Processing Record 1 of Set 8 | miles city
# Processing Record 2 of Set 8 | contamana
# Processing Record 3 of Set 8 | bilma
# Processing Record 4 of Set 8 | qidong
# Processing Record 5 of Set 8 | burnie
# Processing Record 6 of Set 8 | ahipara
# Processing Record 7 of Set 8 | seremban
# Processing Record 8 of Set 8 | visby
# Processing Record 9 of Set 8 | cayenne
# Processing Record 10 of Set 8 | bilibino
# Processing Record 11 of Set 8 | fiumicino
# Processing Record 12 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 8 | carballo
# Processing Record 14 of Set 8 | breves
# Processing Record 15 of Set 8 | awbari
# Processing Record 16 of Set 8 | kapuskasing
# Processing Record 17 of Set 8 | gagra
# Processing Record 18 of Set 8 | nanyamba
# Processing Record 19 of Set 8 | omboue
# Processing Record 20 of Set 8 | kenai
# Processing Record 21 of Set 8 | bourail
# Processing Record 22 of Set 8 | gubkinskiy
# Processing Record 23 of Set 8 | waipawa
# Processing Record 24 of Set 8 | alyangula
# Processing Record 25 of Set 8 | ornes
# Processing Record 26 of Set 8 | dongsheng
# Processing Record 27 of Set 8 | praia
# Processing Record 28 of Set 8 | hofn
# Processing Record 29 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 30 of Set 8 | bauchi
# Processing Record 31 of Set 8 | luwuk
# Processing Record 32 of Set 8 | ulaangom
# Processing Record 33 of Set 8 | ketchikan
# Processing Record 34 of Set 8 | sarangani
# Processing Record 35 of Set 8 | bandarbeyla
# Processing Record 36 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 8 | ongandjera
# Processing Record 38 of Set 8 | wilmington
# Processing Record 39 of Set 8 | chuy
# Processing Record 40 of Set 8 | bernburg
# Processing Record 41 of Set 8 | solnechnyy
# Processing Record 42 of Set 8 | roald
# Processing Record 43 of Set 8 | maniitsoq
# Processing Record 44 of Set 8 | camana
# Processing Record 45 of Set 8 | paita
# Processing Record 46 of Set 8 | quatre cocos
# Processing Record 47 of Set 8 | ipu
# Processing Record 48 of Set 8 | tirlyanskiy
# Processing Record 49 of Set 8 | gimli
# Processing Record 0 of Set 9 | rey bouba
# Processing Record 1 of Set 9 | kupang
# Processing Record 2 of Set 9 | turbat
# Processing Record 3 of Set 9 | gigmoto
# Processing Record 4 of Set 9 | paraiso
# Processing Record 5 of Set 9 | chalus
# Processing Record 6 of Set 9 | ostrovnoy
# Processing Record 7 of Set 9 | pemangkat
# Processing Record 8 of Set 9 | tuy hoa
# Processing Record 9 of Set 9 | mabaruma
# Processing Record 10 of Set 9 | faya
# Processing Record 11 of Set 9 | mount isa
# Processing Record 12 of Set 9 | laguna
# Processing Record 13 of Set 9 | egvekinot
# Processing Record 14 of Set 9 | chitipa
# Processing Record 15 of Set 9 | san quintin
# Processing Record 16 of Set 9 | port lincoln
# Processing Record 17 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 9 | la grande
# Processing Record 19 of Set 9 | pionerskiy
# Processing Record 20 of Set 9 | sharjah
# Processing Record 21 of Set 9 | goianesia
# Processing Record 22 of Set 9 | yeniseysk
# Processing Record 23 of Set 9 | susanville
# Processing Record 24 of Set 9 | narok
# Processing Record 25 of Set 9 | fevik
# Processing Record 26 of Set 9 | salalah
# Processing Record 27 of Set 9 | at-bashi
# Processing Record 28 of Set 9 | mutis
# Processing Record 29 of Set 9 | luba
# Processing Record 30 of Set 9 | conde
# Processing Record 31 of Set 9 | devarkonda
# Processing Record 32 of Set 9 | iisalmi
# Processing Record 33 of Set 9 | mahbubabad
# Processing Record 34 of Set 9 | hamilton
# Processing Record 35 of Set 9 | hai phong
# City not found. Skipping...
# Processing Record 36 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 9 | floriano
# Processing Record 39 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 9 | te anau
# Processing Record 41 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 9 | gazanjyk
# Processing Record 43 of Set 9 | bela vista
# Processing Record 44 of Set 9 | hasaki
# Processing Record 45 of Set 9 | hostotipaquillo
# Processing Record 46 of Set 9 | constitucion
# Processing Record 47 of Set 9 | usinsk
# Processing Record 48 of Set 9 | cabo san lucas
# Processing Record 49 of Set 9 | pacific grove
# Processing Record 0 of Set 10 | eureka
# Processing Record 1 of Set 10 | tateyama
# Processing Record 2 of Set 10 | massena
# Processing Record 3 of Set 10 | lagunas
# Processing Record 4 of Set 10 | semey
# Processing Record 5 of Set 10 | asau
# Processing Record 6 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 7 of Set 10 | leghorn
# City not found. Skipping...
# Processing Record 8 of Set 10 | mana
# Processing Record 9 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 10 | tecoanapa
# Processing Record 11 of Set 10 | worland
# Processing Record 12 of Set 10 | meiganga
# Processing Record 13 of Set 10 | deputatskiy
# Processing Record 14 of Set 10 | warrnambool
# Processing Record 15 of Set 10 | cieza
# Processing Record 16 of Set 10 | kot putli
# City not found. Skipping...
# Processing Record 17 of Set 10 | necochea
# Processing Record 18 of Set 10 | pangnirtung
# Processing Record 19 of Set 10 | koslan
# Processing Record 20 of Set 10 | aimores
# Processing Record 21 of Set 10 | itarema
# Processing Record 22 of Set 10 | nortelandia
# Processing Record 23 of Set 10 | luis correia
# Processing Record 24 of Set 10 | chifeng
# Processing Record 25 of Set 10 | flinders
# Processing Record 26 of Set 10 | haines junction
# Processing Record 27 of Set 10 | cururupu
# Processing Record 28 of Set 10 | havelock
# Processing Record 29 of Set 10 | tanabe
# Processing Record 30 of Set 10 | poum
# Processing Record 31 of Set 10 | uryupinsk
# Processing Record 32 of Set 10 | vilhena
# Processing Record 33 of Set 10 | teguise
# Processing Record 34 of Set 10 | quelimane
# Processing Record 35 of Set 10 | bambanglipuro
# Processing Record 36 of Set 10 | merauke
# Processing Record 37 of Set 10 | puerto ayacucho
# Processing Record 38 of Set 10 | lagoa
# Processing Record 39 of Set 10 | lata
# Processing Record 40 of Set 10 | aljezur
# Processing Record 41 of Set 10 | genhe
# Processing Record 42 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 43 of Set 10 | stornoway
# Processing Record 44 of Set 10 | namibe
# Processing Record 45 of Set 10 | granadilla de abona
# Processing Record 46 of Set 10 | miedzyrzecz
# Processing Record 47 of Set 10 | laem sing
# Processing Record 48 of Set 10 | ozernovskiy
# Processing Record 49 of Set 10 | cockburn town
# Processing Record 0 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 11 | lavrentiya
# Processing Record 2 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 3 of Set 11 | rio gallegos
# Processing Record 4 of Set 11 | sorland
# Processing Record 5 of Set 11 | kuching
# Processing Record 6 of Set 11 | dauphin
# Processing Record 7 of Set 11 | kidal
# Processing Record 8 of Set 11 | faro
# Processing Record 9 of Set 11 | kutum
# Processing Record 10 of Set 11 | hjelset
# Processing Record 11 of Set 11 | sao filipe
# Processing Record 12 of Set 11 | ypsilanti
# Processing Record 13 of Set 11 | iracoubo
# Processing Record 14 of Set 11 | borisovka
# Processing Record 15 of Set 11 | muros
# Processing Record 16 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 11 | kunyang
# Processing Record 18 of Set 11 | pontianak
# Processing Record 19 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 11 | san pedro
# Processing Record 21 of Set 11 | altay
# Processing Record 22 of Set 11 | muana
# Processing Record 23 of Set 11 | dunedin
# Processing Record 24 of Set 11 | borama
# City not found. Skipping...
# Processing Record 25 of Set 11 | mbandaka
# Processing Record 26 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 27 of Set 11 | kabo
# Processing Record 28 of Set 11 | hakkari
# Processing Record 29 of Set 11 | liverpool
# Processing Record 30 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 31 of Set 11 | toora-khem
# Processing Record 32 of Set 11 | meulaboh
# Processing Record 33 of Set 11 | barabai
# Processing Record 34 of Set 11 | oudtshoorn
# Processing Record 35 of Set 11 | hobyo
# Processing Record 36 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 11 | rawson
# Processing Record 38 of Set 11 | alekseyevka
# Processing Record 39 of Set 11 | trinidad
# Processing Record 40 of Set 11 | keti bandar
# Processing Record 41 of Set 11 | antibes
# Processing Record 42 of Set 11 | dingle
# Processing Record 43 of Set 11 | otjimbingwe
# Processing Record 44 of Set 11 | homer
# Processing Record 45 of Set 11 | dinar
# Processing Record 46 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 47 of Set 11 | hearst
# Processing Record 48 of Set 11 | oneonta
# Processing Record 49 of Set 11 | maumere
# Processing Record 0 of Set 12 | keetmanshoop
# Processing Record 1 of Set 12 | buala
# Processing Record 2 of Set 12 | urumqi
# Processing Record 3 of Set 12 | brownsville
# Processing Record 4 of Set 12 | san patricio
# Processing Record 5 of Set 12 | ust-omchug
# Processing Record 6 of Set 12 | rodrigues alves
# Processing Record 7 of Set 12 | ust-koksa
# Processing Record 8 of Set 12 | chissamba
# Processing Record 9 of Set 12 | nantucket
# Processing Record 10 of Set 12 | de aar
# Processing Record 11 of Set 12 | yantzaza
# Processing Record 12 of Set 12 | kargapolye
# City not found. Skipping...
# Processing Record 13 of Set 12 | shache
# Processing Record 14 of Set 12 | cueto
# Processing Record 15 of Set 12 | shieli
# Processing Record 16 of Set 12 | yelizovo
# Processing Record 17 of Set 12 | albury
# Processing Record 18 of Set 12 | beroroha
# Processing Record 19 of Set 12 | taldan
# Processing Record 20 of Set 12 | fort nelson
# Processing Record 21 of Set 12 | maceio
# Processing Record 22 of Set 12 | santa maria
# Processing Record 23 of Set 12 | santarem
# Processing Record 24 of Set 12 | salinopolis
# Processing Record 25 of Set 12 | stillwater
# Processing Record 26 of Set 12 | saint-joseph
# Processing Record 27 of Set 12 | kailua
# Processing Record 28 of Set 12 | longyan
# Processing Record 29 of Set 12 | aden
# Processing Record 30 of Set 12 | katherine
# Processing Record 31 of Set 12 | baghdad
# Processing Record 32 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 12 | mnogovershinnyy
# Processing Record 34 of Set 12 | tarbert
# Processing Record 35 of Set 12 | pingliang
# Processing Record 36 of Set 12 | banjarmasin
# Processing Record 37 of Set 12 | barbastro
# Processing Record 38 of Set 12 | plouzane
# Processing Record 39 of Set 12 | davila
# Processing Record 40 of Set 12 | manjeshwar
# Processing Record 41 of Set 12 | atar
# Processing Record 42 of Set 12 | khandyga
# Processing Record 43 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 12 | mbalmayo
# Processing Record 45 of Set 12 | nshamba
# Processing Record 46 of Set 12 | urfa
# City not found. Skipping...
# Processing Record 47 of Set 12 | aklavik
# Processing Record 48 of Set 12 | anadyr
# Processing Record 49 of Set 12 | daru
# Processing Record 0 of Set 13 | ourem
# Processing Record 1 of Set 13 | ligayan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Show Record Count
city_data_pd.count()
# Out:
# City          547
# Lat           547
# Lng           547
# Max Temp      547
# Humidity      547
# Cloudiness    547
# Wind Speed    547
# Country       547
# Date          547
# dtype: int64

# %%
city_data_pd
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    ribeira grande  38.5167  -28.7000     61.20        63          40
# 1         saskylakh  71.9167  114.0833     -5.35       100          25
# 2           mataura -46.1927  168.8643     52.48        87         100
# 3      longyearbyen  78.2186   15.6401      9.84        77          30
# 4           talnakh  69.4865   88.3972     -3.62       100          48
# ..              ...      ...       ...       ...       ...         ...
# 542         aklavik  68.2191 -135.0107     17.60        93           0
# 543          anadyr  64.7500  177.4833     18.10        86           0
# 544            daru  -9.0763  143.2092     79.21        86         100
# 545           ourem  39.6417   -8.5919     68.92        62          92
# 546         ligayan   4.6533  119.4706     84.06        76          66
#
#      Wind Speed Country        Date
# 0         23.02      PT  1650812012
# 1          2.89      RU  1650812013
# 2          6.22      NZ  1650812014
# 3          5.32      SJ  1650812014
# 4          2.28      RU  1650812015
# ..          ...     ...         ...
# 542        5.75      CA  1650812386
# 543        6.71      RU  1650812386
# 544        6.24      PG  1650812387
# 545        4.90      PT  1650812387
# 546        9.10      PH  1650812388
#
# [547 rows x 9 columns]

# %%
city_data_pd.to_csv('filename.csv')
# Out:
#   File "C:\Users\use\AppData\Local\Temp/ipykernel_7296/2656793964.py", line 1
#     city_data_pd.to_csv(WeathPy"/filename.csv')
#                                                ^
# SyntaxError: EOL while scanning string literal
